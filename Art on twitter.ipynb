# %% [markdown]
# Goal: gauge ingagement between tradition and digital art on twitter

# %%
import requests
import pandas as pd
import json
import urllib
import matplotlib

# %% [markdown]
# Linking to the Twitter API

# %%
bearer_token = pd.read_csv("twitterApp.txt", header = 0)

# %%
token = bearer_token['Bearer Token'].iloc[0]

# %%
header = {'Authorization' : 'Bearer {}'.format(token)}

# %%
endpoint_url = 'https://api.twitter.com/2/tweets/search/recent'

# %% [markdown]
# Query to display posts using the hashtags of digital and traditional art

# %%
query = urllib.parse.quote('(#digitalart OR #traditionalart) -is:retweet')

# %%
tweet_fields = 'author_id,id,text,public_metrics,created_at,entities'

# %%
url = endpoint_url + '?query={}&tweet.fields={}&user.fields={}&max_results=100'.format(query,tweet_fields,"username")

# %%
response_1 = requests.request("GET", url, headers=header)

# %%
response_1_dict = json.loads(response_1.text)

# %%
page1 = pd.DataFrame(response_1_dict['data'])

# %%
page1
# Out:
#                                        public_metrics  \
# 0   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 3   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 4   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ..                                                ...
# 95  {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 96  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 97  {'retweet_count': 0, 'reply_count': 2, 'like_c...
# 98  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 99  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                              entities  \
# 0   {'mentions': [{'start': 0, 'end': 9, 'username...
# 1   {'mentions': [{'start': 0, 'end': 8, 'username...
# 2   {'mentions': [{'start': 0, 'end': 9, 'username...
# 3   {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 4   {'hashtags': [{'start': 74, 'end': 85, 'tag': ...
# ..                                                ...
# 95  {'annotations': [{'start': 16, 'end': 21, 'pro...
# 96  {'annotations': [{'start': 27, 'end': 33, 'pro...
# 97  {'hashtags': [{'start': 71, 'end': 87, 'tag': ...
# 98  {'hashtags': [{'start': 12, 'end': 16, 'tag': ...
# 99  {'hashtags': [{'start': 0, 'end': 5, 'tag': 'n...
#
#                                                  text  \
# 0   @SNFonNBC @NBCSports BIG NEWS Top Crypto Gaine...
# 1   @opensea \n https://t.co/dDV3ecIzTb\n.\n#nftar...
# 2   @Quackity @Ranboosaysstuff BIG NEWS Top Crypto...
# 3   @Ranboosaysstuff BIG NEWS Top Crypto Gainers =...
# 4   blue haired girl.😍 adopt ne soon  with 0.005 e...
# ..                                                ...
# 95  Before you meet Hokori in chapter 1, I want to...
# 96  Hey all! Here's my take on Caitlyn and Vi from...
# 97  Commission Open Now\nDM me if interested&lt;3\...
# 98  Zombie Baby\n#art #illustration #digitalart #n...
# 99  #nfts #nft #nftart #nftartist #nftcollector #c...
#
#                   created_at            author_id                   id
# 0   2021-11-30T21:51:57.000Z   780399227675475968  1465800793962037249
# 1   2021-11-30T21:51:46.000Z  1461067796046036994  1465800748223152130
# 2   2021-11-30T21:51:44.000Z   780399227675475968  1465800739566104582
# 3   2021-11-30T21:51:28.000Z   780399227675475968  1465800673631604741
# 4   2021-11-30T21:51:26.000Z  1458706080066949121  1465800665381457927
# ..                       ...                  ...                  ...
# 95  2021-11-30T21:41:06.000Z  1401286275152461834  1465798064065634307
# 96  2021-11-30T21:40:52.000Z  1353067640843952128  1465798005924065280
# 97  2021-11-30T21:40:44.000Z  1444856854614458370  1465797971748950020
# 98  2021-11-30T21:40:34.000Z  1454344433529393155  1465797931903164424
# 99  2021-11-30T21:40:30.000Z  1357472970705416193  1465797911892180992
#
# [100 rows x 6 columns]

# %%
metrics = pd.DataFrame(list(page1['public_metrics']))

# %%
metrics
# Out:
#     retweet_count  reply_count  like_count  quote_count
# 0               0            0           0            1
# 1               0            0           1            0
# 2               0            0           0            0
# 3               0            0           0            0
# 4               0            0           1            0
# ..            ...          ...         ...          ...
# 95              2            0           2            0
# 96              0            0           0            0
# 97              0            2           0            0
# 98              0            0           3            0
# 99              0            0           3            0
#
# [100 rows x 4 columns]
